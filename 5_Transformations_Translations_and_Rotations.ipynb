# %% [markdown]
# <a href="https://colab.research.google.com/github/Beel17/opencv_learn/blob/main/5_Transformations_Translations_and_Rotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/logo_MCV_W.png)
#
#
# # **Transformations - Translations and Rotations**
#
# In this lesson we'll learn to:
# 1. Perform Image Translations
# 2. Rotations with getRotationMatrix2D
# 3. Rotations with Transpose
# 4. Flipping Images

# %%
# Our Setup, Import Libaries, Create our Imshow Function and Download our Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# Download and unzip our images
from google.colab import drive
import os

# Mount your Google Drive
drive.mount('/content/drive',force_remount=True)

# Specify the path to your images folder on Google Drive
images_folder_path = '/content/drive/MyDrive/natural_images'  # Replace with your actual path

# Create a new directory in Colab to store the downloaded images
local_images_folder = 'downloaded_images'
os.makedirs(local_images_folder, exist_ok=True)

# Iterate through files in the Google Drive folder and download them
# Iterate through files in the Google Drive folder and download them
for filename in os.listdir(images_folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions as needed
        file_path = os.path.join(images_folder_path, filename)
        local_file_path = os.path.join(local_images_folder, filename)
        shutil.copy(file_path, local_file_path)
        print(f"Downloaded {filename}")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Translations**
#
# This an affine transform that simply shifts the position of an image. (left or right).
#
# We use cv2.warpAffine to implement these transformations.
#
# ```cv2.warpAffine(image, T, (width, height))```
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/warp.png)

# %%
# Load our image
image = cv2.imread('/content/drive/MyDrive/natural_images/cat/cat_0060.jpg')
imshow("Original", image)

# Store height and width of the image
height, width = image.shape[:2]

# We shift it by quarter of the height and width
quarter_height, quarter_width = height/4, width/4

# Our Translation
#       | 1 0 Tx |
#  T  = | 0 1 Ty |

# T is our translation matrix
T = np.float32([[1, 0, quarter_width], [0, 1,quarter_height]])

# We use warpAffine to transform the image using the matrix, T
img_translation = cv2.warpAffine(image, T, (width, height))
imshow("Translated", img_translation)

# %%
# What does T look like
print(T)

print(height, width )
# Out:
# [[ 1.   0.  48.5]
#  [ 0.   1.  54. ]]
# 216 194

# %% [markdown]
# ### **Rotations**
#
# ```cv2.getRotationMatrix2D(rotation_center_x, rotation_center_y, angle of rotation, scale)```
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/rotation.png)

# %%
# Load our image
image = cv2.imread('/content/drive/MyDrive/natural_images/cat/cat_0060.jpg')
height, width = image.shape[:2]

# Divide by two to rototate the image around its centre
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 180, 0.5)

# Input our image, the rotation matrix and our desired final width and height
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
imshow("Rotated 90 degrees with scale = 1", rotated_image)

# %%
# Divide by two to rototate the image around its centre
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 0.5)
print(rotation_matrix)
# Input our image, the rotation matrix and our desired final width and height
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
imshow("Rotated 90 degrees with scale = 0.5", rotated_image)
# Out:
# [[ 3.061617e-17  5.000000e-01  4.300000e+01]
#  [-5.000000e-01  3.061617e-17  1.565000e+02]]

# %% [markdown]
# Notice all the black space surrounding the image.
#
# We could now crop the image as we can calculate it's new size (we haven't learned cropping yet!).
#
# ### **Rotations with cv2.transpose** (less flexible)

# %%
rotated_image = cv2.transpose(image)
imshow("Original", image)
imshow("Rotated using Transpose", rotated_image)

# %%
rotated_image = cv2.transpose(image)
rotated_image = cv2.transpose(rotated_image)

imshow("Rotated using Transpose", rotated_image)

# %%
# Let's now to a horizontal flip.
flipped = cv2.flip(image, 1)
imshow("Horizontal Flip", flipped)
